# %%
 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import networkx as nx
from networkx.algorithms import community

# %%
dff= pd.read_csv("/content/drive/MyDrive/bigdata/graphs/c_combined_edges_w_1_s_0.9.csv")

# %%
dff.head()
# Out:
#    Source  Target  Weight    Sim
# 0       1     168      30  0.975
# 1       4      56      13  0.974
# 2     149     244      12  1.000
# 3     198     244       4  1.000
# 4       1     244      16  1.000

# %%
dff=dff.iloc[200:400,:]

# %%
def graph(data):
  G=nx.DiGraph()
  
  edges=list(dff.apply(lambda x: (x[0],x[1],x[2]), axis=1)) # i took the source and target and the wheight
  G.add_weighted_edges_from(edges) # Relation

  communities_generator = community.girvan_newman(G)
  top_level_communities = next(communities_generator)
  next_level_communities = next(communities_generator)
  comm=sorted(map(sorted, next_level_communities))

  nx.draw(G,with_labels=True)

  return G

# %%
G=graph(dff)

# %%
nx.write_gexf(G, 'network.gexf')

# %%
nx.info(G)
# Out:
# 'Name: \nType: DiGraph\nNumber of nodes: 75\nNumber of edges: 200\nAverage in degree:   2.6667\nAverage out degree:   2.6667'

# %%
nx.clustering(G)
# Out:
# {1.0: 0,
#  3.0: 0.14333333333333334,
#  4.0: 0,
#  17.0: 0.4010989010989011,
#  18.0: 0.3333333333333333,
#  20.0: 0.5,
#  25.0: 0.5,
#  33.0: 0.3901098901098901,
#  34.0: 0.5,
#  35.0: 0.5,
#  45.0: 0,
#  48.0: 0.5,
#  56.0: 0,
#  60.0: 0,
#  84.0: 0.16666666666666666,
#  91.0: 0.5,
#  98.0: 0.5,
#  122.0: 0.1346153846153846,
#  129.0: 0,
#  137.0: 0.3125,
#  144.0: 0.28431372549019607,
#  147.0: 0,
#  149.0: 0.5,
#  160.0: 0.5,
#  168.0: 0.10416666666666667,
#  170.0: 0.4166666666666667,
#  171.0: 0.5,
#  183.0: 0.3333333333333333,
#  185.0: 0.4166666666666667,
#  187.0: 0.5,
#  194.0: 0,
#  196.0: 0.3333333333333333,
#  204.0: 0.5,
#  205.0: 0.36666666666666664,
#  218.0: 0.3,
#  220.0: 0.5,
#  226.0: 0,
#  227.0: 0.5,
#  229.0: 0,
#  232.0: 0,
#  236.0: 0.10606060606060606,
#  237.0: 0.5,
#  238.0: 0.4166666666666667,
#  239.0: 0.4166666666666667,
#  240.0: 0.5,
#  241.0: 0.3333333333333333,
#  244.0: 0.3333333333333333,
#  251.0: 0.0989010989010989,
#  257.0: 0.2875,
# ...

# %%
nx.betweenness_centrality(G)
# Out:
# {1.0: 0.0,
#  3.0: 0.020825620140688634,
#  4.0: 0.00018511662347278786,
#  17.0: 9.255831173639393e-05,
#  18.0: 0.0,
#  20.0: 0.0,
#  25.0: 0.0,
#  33.0: 0.0010181414291003331,
#  34.0: 0.0,
#  35.0: 0.0,
#  45.0: 0.0,
#  48.0: 0.0,
#  56.0: 0.0,
#  60.0: 0.0007404664938911515,
#  84.0: 0.0,
#  91.0: 0.0,
#  98.0: 0.0,
#  122.0: 0.003517215845982969,
#  129.0: 0.0,
#  137.0: 0.0031778353696161918,
#  144.0: 0.003918301863507344,
#  147.0: 0.0,
#  149.0: 0.0,
#  160.0: 0.0,
#  168.0: 0.004813032210292485,
#  170.0: 0.0,
#  171.0: 0.0,
#  183.0: 0.0,
#  185.0: 0.0,
#  187.0: 0.0,
#  194.0: 0.0,
#  196.0: 0.0,
#  204.0: 0.0,
#  205.0: 0.00018511662347278786,
#  218.0: 0.00046279155868196966,
#  220.0: 0.0,
#  226.0: 0.0,
#  227.0: 0.0,
#  229.0: 0.0,
#  232.0: 0.0,
#  236.0: 0.004257682339874121,
#  237.0: 0.0,
#  238.0: 0.00018511662347278786,
#  239.0: 0.00018511662347278786,
#  240.0: 0.0,
#  241.0: 9.255831173639393e-05,
#  244.0: 0.00018511662347278786,
#  251.0: 0.0,
# ...

# %%
for node in G.nodes():
    print(node, nx.degree_centrality(G)[node])
# Out:
# 238.0 0.05405405405405406
# 251.0 0.1891891891891892
# 168.0 0.21621621621621623
# 91.0 0.02702702702702703
# 185.0 0.05405405405405406
# 236.0 0.16216216216216217
# 149.0 0.02702702702702703
# 170.0 0.05405405405405406
# 183.0 0.04054054054054054
# 1.0 0.013513513513513514
# 122.0 0.17567567567567569
# 239.0 0.05405405405405406
# 196.0 0.04054054054054054
# 60.0 0.02702702702702703
# 237.0 0.02702702702702703
# 18.0 0.04054054054054054
# 244.0 0.04054054054054054
# 34.0 0.04054054054054054
# 25.0 0.02702702702702703
# 260.0 0.013513513513513514
# 229.0 0.013513513513513514
# 434.0 0.013513513513513514
# 362.0 0.013513513513513514
# 588.0 0.013513513513513514
# 654.0 0.013513513513513514
# 636.0 0.013513513513513514
# 361.0 0.02702702702702703
# 573.0 0.013513513513513514
# 411.0 0.013513513513513514
# 762.0 0.013513513513513514
# 648.0 0.02702702702702703
# 668.0 0.02702702702702703
# 269.0 0.02702702702702703
# 144.0 0.24324324324324326
# 295.0 0.16216216216216217
# ...

# %%
communities_generator = community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communitµies = next(communities_generator)
comm=sorted(map(sorted, next_level_communities))

# %%
import numpy as np
import pandas as pd
comm=np.array(comm)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
dictionary=dict()

for i in range(len(comm)):
  dictionary[f"community {i+1}"]=np.array(comm[i])

# %%
dictionary
# Out:
# {'community 1': array([  1.,  18.,  25.,  34.,  48.,  91., 122., 149., 168., 170., 183.,
#         185., 196., 232., 236., 237., 238., 239., 244., 251., 260.]),
#  'community 10': array([479., 550.]),
#  'community 11': array([588., 654.]),
#  'community 2': array([  3.,  17.,  20.,  33.,  45.,  98., 129., 137., 144., 160., 171.,
#         187., 204., 205., 218., 220., 227., 240., 241., 257., 265., 267.,
#         282., 295., 309., 315., 339., 444., 463., 465., 570.]),
#  'community 3': array([  4.,  56., 194., 226.]),
#  'community 4': array([ 35.,  84., 147.]),
#  'community 5': array([ 60., 229.]),
#  'community 6': array([269., 648., 668.]),
#  'community 7': array([361., 573., 636.]),
#  'community 8': array([362., 434.]),
#  'community 9': array([411., 762.])}
